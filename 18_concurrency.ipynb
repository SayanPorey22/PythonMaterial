# %% [markdown]
# > Part of **Complete Python Study Material** — split across per-chapter notebooks. See [`00_index.ipynb`](00_index.ipynb) for the notebook conventions, per-concept template, status tags, the Inbox, the digitalization log, chapter coverage tracker and cross-reference index.

# %% [markdown]
# ## 18. Concurrency: Multitasking, Threads and Processes
#
# *Scope:* Doing more than one thing at a time, and what Python actually allows.

# %% [markdown]
# ### 18.1 Concurrency Concepts and Terminology
#
# > _Content to be added from handwritten notes._

# %% [markdown]
# ### 18.2 Multithreading
#
# > _Content to be added from handwritten notes._

# %% [markdown]
# ### 18.3 Thread Synchronization
#
# > _Content to be added from handwritten notes._

# %% [markdown]
# ### 18.4 Multiprocessing
#
# > _Content to be added from handwritten notes._

# %% [markdown]
# ### 18.5 The GIL and Performance Implications
#
# > _Content to be added from handwritten notes._
#
# *Referenced from 1.1.6 as a cause of the performance limitation.*

# %% [markdown]
# ### 18.6 Asynchronous Programming
#
# > _Content to be added from handwritten notes._

# %% [markdown]
# ### 18.7 Choosing a Concurrency Model
#
# > _Content to be added from handwritten notes._

# %% [markdown]
# ### 18.9 Additional Concurrency Concepts From Notes
#
# Overflow bucket for this chapter — small or unclassified items that clearly belong to
# this domain but not yet to a specific section above.
#
# > _Content to be added from handwritten notes._

# %%
# --- 18. Concurrency: Multitasking, Threads and Processes — scratch cell ---
# Experiments for this chapter. Promote anything worth keeping into the
# relevant section as a proper example cell.
