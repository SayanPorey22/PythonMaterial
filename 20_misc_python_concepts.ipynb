# %% [markdown]
# > Part of **Complete Python Study Material** — split across per-chapter notebooks. See [`00_index.ipynb`](00_index.ipynb) for the notebook conventions, per-concept template, status tags, the Inbox, the digitalization log, chapter coverage tracker and cross-reference index.

# %% [markdown]
# ## 20. Miscellaneous Python Concepts
#
# *Scope:* Small, self-contained concepts that do not warrant a chapter of their own. A concept lives here only if it has no better home elsewhere.

# %% [markdown]
# ### 20.1 Keywords and Reserved Words
#
# > _Content to be added from handwritten notes._

# %% [markdown]
# ### 20.2 Built-in Functions: Notes and Behaviour
#
# > _Content to be added from handwritten notes._

# %% [markdown]
# ### 20.3 Dynamic Execution: `eval`, `exec`, `compile`
#
# > _Content to be added from handwritten notes._

# %% [markdown]
# ### 20.4 Small Language Behaviours and Tricks
#
# > _Content to be added from handwritten notes._

# %% [markdown]
# ### 20.5 Comparisons Between Similar Concepts
#
# > _Content to be added from handwritten notes._

# %% [markdown]
# ### 20.6 Edge Cases and Gotchas
#
# > _Content to be added from handwritten notes._

# %% [markdown]
# ### 20.7 Interview-Oriented Facts
#
# > _Content to be added from handwritten notes._

# %% [markdown]
# ### 20.8 Version Differences and Deprecations
#
# > _Content to be added from handwritten notes._

# %% [markdown]
# ### 20.9 Additional Miscellaneous Python Concepts Concepts From Notes
#
# Overflow bucket for this chapter — small or unclassified items that clearly belong to
# this domain but not yet to a specific section above.
#
# > _Content to be added from handwritten notes._

# %%
# --- 20. Miscellaneous Python Concepts — scratch cell ---
# Experiments for this chapter. Promote anything worth keeping into the
# relevant section as a proper example cell.
