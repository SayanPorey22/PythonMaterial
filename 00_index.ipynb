# %% [markdown]
# # Complete Python Study Material
#
# **A personal, exhaustive Python learning and reference notebook.**
#
# Status: `structural skeleton (v2)` — headings and extension points only.
# Content is inserted incrementally from handwritten notes.
#
# This is the **index notebook**. Chapters 1–20 each live in their own file in this folder (e.g. `01_python_fundamentals.ipynb`); this file holds the shared conventions (Chapter 0) and the Appendix (23) — the parts that apply across chapters rather than to one of them.
#
# ---

# %% [markdown]
# ## 0. How to Use This Notebook
#
# This chapter is the only part of the notebook that is *not* filled from the handwritten
# notes. It documents the conventions that keep the structure stable while the content grows.

# %% [markdown]
# ### 0.1 Purpose and Scope
#
# This notebook is intended to become a single, complete Python reference built from a
# detailed set of handwritten notes.
#
# * The chapter list (top level) is meant to stay **stable**.
# * Sub-sections are meant to be **split, renamed and deepened** as notes arrive.
# * Nothing here is a syllabus to be followed — it is a set of containers to be filled.

# %% [markdown]
# ### 0.2 Source of Truth
#
# The **handwritten notes are authoritative** for:
#
# * which concepts exist,
# * how deep each concept goes,
# * which examples, experiments, edge cases and observations are recorded,
# * the wording of definitions where the notes are explicit.
#
# Where a section here has no matching note yet, it stays as a placeholder rather than being
# filled with generic material.

# %% [markdown]
# ### 0.3 Per-Concept Documentation Template
#
# Full style guide: [`CLAUDE.md`](CLAUDE.md). Summary — every concept is
# **explanation + runnable demo, never one alone**:
#
# 1. A markdown cell with a real explanation — not a one-liner. Use whatever fits best: a
#    small table (operators, types, syntax forms), a short "why it matters" note, a named
#    callout for a nuance or gotcha (`**Common mistake** — ...`), or a contrast with a
#    related/confusable concept.
# 2. One or more **actual code cells** (not fenced ` ```python ` blocks inside markdown),
#    each minimal and focused on one thing — a couple of `print()` calls with an inline `#`
#    comment showing the expected output.
# 3. A concept-specific gotcha or a second angle worth showing gets its own small
#    markdown note + its own small code cell, rather than one giant cell for everything.
#
# Make abstract ideas (identity, mutability, the object model) tangible — e.g. print
# `id()` side by side instead of only describing it in prose.

# %% [markdown]
# ### 0.4 Cell Rhythm for Each Concept
#
# The cell sequence when a concept is written up:
#
# ```text
# Markdown  ->  explanation (table / prose / "why it matters")
# Code      ->  minimal runnable demo, inline # comments show expected output
# Markdown  ->  (optional) a named gotcha or second angle
# Code      ->  (optional) its own small demo cell
# ```
#
# Repeat per concept/sub-concept. Each chapter ends with a scratch cell for ad-hoc
# experiments — promote anything worth keeping into a proper section instead of leaving it
# there.

# %% [markdown]
# ### 0.5 Numbering and Insertion Rules
#
# Conventions that avoid renumbering the whole notebook every time a note is added:
#
# 1. **Chapter numbers are frozen.** New major domains are appended, never inserted.
# 2. **New sub-sections are appended** to the end of a chapter, before the `x.9` bucket
#    (if the chapter has one — see rule 3).
# 3. **`x.9 Additional ... From Notes`** is an *optional* per-chapter overflow bucket.
#    Anything with no obvious home can land here first and migrate once a pattern
#    emerges — but a chapter that is otherwise complete does not need to keep an empty
#    one around; it can be dropped.
# 4. **Deeper levels are free-form.** `13.5.2`, `13.5.3` etc. can be created and reordered
#    without touching anything above them.
# 5. **Moving, renaming or removing a section** means updating the cells and fixing any
#    pointer that referenced the old location — in other chapters and in the Appendix
#    (§23.2, §23.3) — rather than leaving it dangling.

# %% [markdown]
# ### 0.6 Status Tags
#
# **Deprecated — not used from chapter 2 onward.** Section headings stay clean (no
# `[DONE]`/`[EMPTY]`/...); use §23.2's Chapter Coverage Tracker instead to track what's
# filled vs. outstanding. Kept here only as a historical note — chapter 1 briefly used:
#
# * `[EMPTY]` — nothing transferred yet
# * `[PARTIAL]` — some notes transferred, more exist on paper
# * `[DONE]` — notes fully transferred
# * `[VERIFY]` — transferred but the behaviour has not been re-tested in code
# * `[EXPAND]` — needs more examples or experiments than the notes contain

# %% [markdown]
# ### 0.7 Incremental Workflow
#
# ```text
# Phase 1   Build the skeleton                        <- current state
# Phase 2   Transfer notes for one domain at a time
# Phase 3   Expand that chapter's sub-sections
# Phase 4   Repeat until the handwritten notes are exhausted
# ```
#
# Small or scattered concepts are filed directly into their most relevant chapter section
# as they come up, rather than held in a separate staging area. Unrelated chapters are
# never restructured to accommodate a single new concept.

# %% [markdown]
# ### 0.8 File Layout
#
# The notebook was originally a single file; it is now split for size and editability:
#
# * `00_index.ipynb` (this file) — Chapter 0 conventions, Chapter 23 Appendix.
# * `NN_<slug>.ipynb` — one notebook per chapter (1–20), e.g. `01_python_fundamentals.ipynb`.
#
# Chapter numbering, the per-concept template, status tags and the `.9` overflow-bucket convention are unchanged — they now just apply within each chapter's own file. In-notebook `see also` pointers (e.g. "see 2.6") refer to a section number, not a file path; resolve them by chapter number to the matching `NN_*.ipynb`.

# %% [markdown]
# ## 23. Appendix
#
# *Scope:* Bookkeeping for the digitalization process itself, not Python content.

# %% [markdown]
# ### 23.1 Digitalization Log
#
# One row per transfer session, so it is always clear what remains on paper.
#
# | Date | Notes source (page / section) | Target chapter(s) | Status |
# |---|---|---|---|
# | 2026-08-12 | Opening page — definition, features, limitations, "everything is an object" | 1.1 (1.1.1–1.1.7) | Done |
# | 2026-08-18 | `module_10_notes/` — 9 handwritten pages ("Advanced Python," Videos 1–3 and 42–43): class/object/reference variables, docstrings, `self` identity, no constructor overloading, instance vs. static variables (declaring/accessing/modifying from every context, removing with `del`) | 10.1–10.4 | Done |
# |  |  |  |  |

# %% [markdown]
# ### 23.2 Chapter Coverage Tracker
#
# | Chapter | Status | Remaining |
# |---|---|---|
# | 1. Python Fundamentals | `[DONE]` |  |
# | 2. Objects and Data Types | `[PARTIAL]` | `NoneType`, type conversion, mutability — no section currently plans these |
# | 3. Operators and Expressions | `[DONE]` |  |
# | 4. Flow Control | `[DONE]` | conditionals, loops, loop control, and `else` on loops/`try` only — pattern matching and idioms have no section yet |
# | 5. Built-in Data Types | `[DONE]` | 5.1 List, 5.2 String, 5.3 Set/Frozenset, 5.4 Dictionary, 5.5 Tuple all done |
# | 6. Functions | `[DONE]` | 6.1 Fundamentals, 6.2 Arguments, 6.5 Recursion, 6.6.1 Type Hinting, and 6.8 Functional Programming Concepts (6.8.1 Lambda, 6.8.2 Higher-Order Functions/`map`/`filter`/`reduce`, 6.8.3 Nested Functions/Closures, 6.8.4 Decorators) — includes former "Functional Programming" chapter, merged in as 6.8; unused empty sections (Return Values, Scope/Lifetime, Introspection, First-Class Objects) were removed rather than left as placeholders |
# | 7. Exception Handling | `[DONE]` | 7.1 (errors vs. logical errors vs. exceptions), 7.2 (`try`/`except`/`else`/`finally`, structural rules, nesting), 7.3 (`raise`, bare-`raise` re-raising, implicit chaining via `__context__`, explicit `raise ... from ...` via `__cause__`, suppression via `raise ... from None`), 7.4 (exception hierarchy, common built-ins, bare `except:` gotcha), 7.5 (custom exceptions, hierarchies), 7.6 (practices), 7.9 (`assert`, exception `.args`/`str()`/`repr()`) — all filled; there is no section between 7.6 and 7.9 (the old empty "Cleanup/Context Managers" 7.6 was dropped and former 7.7 renumbered to 7.6) |
# | 8. Logging and Debugging | `[PARTIAL]` | 8.1 (why logging over `print`, uses of logging), 8.2 (logger/handler/formatter roles, the 5 log levels, default level `WARNING`), 8.3 (module-level logger via `getLogger(__name__)`, `basicConfig`, once-per-process/`force=True`, file logging and `filemode` `"a"` vs `"w"`), 8.4 (approaches overview: print/logging/assert/pdb), 8.5 (`breakpoint()`, `pdb` command table, a reproduced session transcript), 8.6 (`assert` as a fail-fast debugging tool, pairing with `pdb`) done — the "tracing" half of 8.6's title (`sys.settrace`-style tooling) is still empty; the 8.9 overflow bucket was dropped (nothing unclassified left to route there) |
# | 9. Modules and Packages | `[DONE]` | 9.1 (what a module is, import forms, special module members `__name__`/`__doc__`/`__file__`/`__package__`/`__dict__`, `dir()`), 9.2 (`sys.path` search order, `sys.modules` caching, `.pyc`/`__pycache__`, `importlib.reload()` and its stale-instance caveat), 9.3 (packages, `__init__.py`, sub-packages, relative imports, `__all__`, namespace packages), 9.4 (scripts vs. modules, the `__main__` guard), 9.5 (`sys.argv`, `argparse`), 9.6 (stdlib catalog), 9.7 (PyPI/`pip`/virtual environments, `sys.prefix` vs. `sys.base_prefix`), 9.9 (circular imports and the fix, `python -m` and its effect on relative imports) — all filled |
# | 10. Object-Oriented Programming: Foundations | `[DONE]` | 10.1 (classes vs. objects, identity, class docstrings/`__doc__`/`help()`, what `self` is via `id()`), 10.2 (opens with a local/instance/class variable-kind overview, local variables and why they vanish, then the instance-vs-class deep dive: attribute lookup order, the mutable-class-attribute gotcha, dynamic attributes/`vars()`, instance attributes created outside `__init__`, removing an instance attribute with `del` both from inside via `self` and from outside via a reference, and the full declare/read/modify-from-every-context table for class attributes including the safe-read-via-instance case), 10.3 (instance/class/static methods, bound vs. unbound), 10.4 (`__new__` vs. `__init__`, default constructor args, the no-constructor-overloading gotcha), 10.5 (public/`_protected`/`__private` and name mangling), 10.6 (`@property` getter/setter/deleter, the motivating "plain attribute" problem), 10.7 (class design — cohesion, single responsibility), 10.9 (`dataclasses`, `object` as the universal base class) — all filled |
# | 11. Object Relationships | `[DONE]` | 11.1 (association — the general "uses-a" relationship, one-directional/bidirectional/multiplicity), 11.2 (aggregation — weak "has-a," independent part lifecycle, part shareable across wholes, proven via `__del__`), 11.3 (composition — strong "owns-a," part's lifecycle tied to the whole, proven via `__del__`, plus a side-by-side aggregation-vs-composition table and the UML diamond notation), 11.4 (delegation — reuse via "has-a" instead of "is-a," a `Stack`-over-`list` example contrasted directly with subclassing `list`), 11.5 (a decision-path diagram and summary table for choosing between association/aggregation/composition/delegation, plus a capstone `Library` example combining all four) — all filled; the 11.9 overflow bucket was dropped (nothing unclassified left to route there) |
# | 12. Inheritance and MRO | `[DONE]` | 12.1 (base/derived classes, "is-a", `isinstance`/`issubclass` across the chain), 12.2 (single/multiple/multilevel/hierarchical/hybrid inheritance, each with its own diagram and demo, the hybrid case set up as a genuine diamond), 12.3 (method overriding), 12.4 (`super()` — four uses: reusing a parent `__init__`, extending an overridden method, cooperative multiple inheritance where `super()` follows the MRO rather than "the direct parent", and the explicit `super(Class, self)` form), 12.5 (the MRO, the C3 linearization formula, the merge operation's four rules, a simple-diamond example traced by hand, a complex textbook example — `K1`/`K2`/`K3`/`Z`, drawn as a shared-leaves tree and traced via a from-scratch, verbose, verified-correct `merge()`/`linearize()` implementation — and a `TypeError`-raising inconsistent-hierarchy example), 12.6 (abstract classes/interfaces — the `NotImplementedError`-by-convention problem, `abc.ABC`/`@abstractmethod` enforcing it at instantiation time, a completed subclass, and abstract properties) — all filled; 12.7 (inheritance pitfalls) and the 12.9 overflow bucket were both dropped (neither had content planned beyond the placeholder) |
# | 13. Special Methods, Overloading and Overriding | `[DONE]` | 13.1 (dunder/magic methods — mechanism, a full catalog table by category including comparison and hashing dunders, marking `__matmul__`/`__rmatmul__`/`__imatmul__` as Python-3.5+-only (PEP 465), a "Python 2 vs. 3 renamed dunders" table (`__div__`/`__idiv__` → `__truediv__`/`__itruediv__`, `next()` → `__next__()`, `__nonzero__` → `__bool__`), `__str__`/`__len__` demo, a `__eq__`/`__lt__` comparison demo covering the `</>` and `==`/`!=` reflected-pairing rules, closing with a "what's allowed" overloading-vs-overriding summary table), 13.2 (operator overloading — `__add__`, reflected methods and why `5 + v1` fails, the classic `sum()`-needs-`__radd__` gotcha and its fix, `__iadd__` vs. falling back to `__add__`, and the full normal/reflected/in-place table for every arithmetic operator, with the `@`/matrix-mult row annotated as Python 3.5+), 13.3 (method and constructor overloading are *not* supported — redefinition just replaces the earlier `def`, demonstrated for both a plain method and `__init__`, the idiomatic default-argument alternative, and a direct contrast with overriding — which *is* fully supported for both), 13.4 (getter/setter methods — traditional `get_x()`/`set_x()`, a pointer to `@property` as the idiomatic alternative, then the four attribute-access dunders in turn: `__getattr__` as a lookup-failure fallback, `__setattr__` running on every assignment plus its classic infinite-recursion trap and the `super()` fix, `__delattr__`, and `__getattribute__` as the most powerful/dangerous of the four) — all filled; 13.5 (container/callable protocols), 13.6 (comparison/hashing protocols), and the 13.9 overflow bucket were all dropped (none had content planned beyond the placeholder) |
# | 14. Iterators and Generators | `[DONE]` | 14.1 (iterable-vs-iterator distinction table, `iter()`/`next()` manual demo, the gotcha that an iterable is reusable while a specific iterator, once exhausted, stays exhausted), 14.2 (the `__iter__`/`__next__` protocol, `StopIteration`, a `for` loop desugared by hand into its literal `iter()`/`next()`/`try`-`except` form), 14.3 (writing a custom iterator class — `Countdown`, `__iter__` returning `self`, `__next__` raising `StopIteration` — plus the gotcha that such a class is its own iterator and so exhausts permanently, unlike a list), 14.4 (generator functions — the `yield` pause/resume mechanism traced step by step, a list-vs-generator `sys.getsizeof` memory comparison, a bounded Fibonacci generator, and an infinite Fibonacci generator consumed lazily via `itertools.islice`), 14.5 (generator expressions — `()` vs. `[]`, single-use exhaustion, the parens-optional `sum(... for ...)` idiom), 14.6 (advanced generator behaviour — `send()` for two-way communication, `close()`, `yield from` delegation), 14.7 (a closing lazy-vs-eager comparison table, and the `len()`/indexing `TypeError`s a generator raises that a list wouldn't) — all filled |
# | 15. Regular Expressions | `[DONE]` | 15.1 (what a regex is — a pattern language for a *shape* of text rather than one literal string — general applications: validation/searching/replacement/splitting, a plain-string-methods-vs-regex motivating comparison), 15.2 (the `re` module — patterns as ordinary strings, the raw-string-vs-plain-string escape gotcha, `re.compile()` for a reusable `Pattern` object, `.finditer()` as a lazy iterator of `Match` objects with `.group()`/`.start()`/`.end()`/`.span()`), 15.3 (character classes — `[...]`, ranges, negation via a leading `^`), 15.4 (predefined character classes — `\d`/`\D`/`\w`/`\W`/`\s`/`\S`/`.`, plus the `\b` word-boundary gotcha), 15.5 (quantifiers — `*`/`+`/`?`/`{n}`/`{n,}`/`{n,m}`, and the greedy-vs-lazy `?`-suffix distinction via a classic HTML-tag example), 15.6 (a full function catalog table — `match`/`fullmatch`/`search`/`findall`/`finditer`/`sub`/`subn`/`split`/`compile`/`escape` — with a short demo for every one) — all filled |
# | 16. File Handling | `[DONE]` | 16.1 (why file handling exists — persisting data beyond a process's lifetime; in-memory vs. temporary vs. permanent storage; text vs. binary files, with an `.encode()` demo showing exactly where the two diverge), 16.2 (text file open modes — `r`/`w`/`a`/`x`/`r+`/`w+`/`a+`, each demonstrated, including `x`'s `FileExistsError` and `r+`'s no-truncation overwrite), 16.3 (every binary counterpart — `rb`/`wb`/`ab`/`xb`/`rb+`/`wb+`/`ab+` — as a one-liner table, plus a minimal `wb`/`rb` demo), 16.4 (the file object's properties — `.name`/`.mode`/`.encoding`/`.closed`/`.writable()`/`.readable()` — `.write()`'s return value, and how `open()` resolves a path: relative-to-cwd vs. absolute, plus building a portable path with `os.path.join()`/`pathlib`), 16.5 (`.read(n)`/`.read()`/`.readline()`/`.readlines()` compared, then iterating the file object directly as the idiomatic lazy line-by-line approach), 16.6 (the `with` statement — why a bare `.close()` can be skipped by an exception, `__enter__`/`__exit__` guaranteeing it runs regardless), 16.7 (other structured formats — CSV/JSON/Excel/PDF summarized in one table, a full `csv.writer`/`csv.reader`/`csv.DictReader` demo, and reference syntax for `openpyxl` and `pypdf`, neither of which is stdlib) — all filled |
# | 17. Concurrency | `[DONE]` | 17.1 (thread vs. process, concurrency vs. parallelism with a static ASCII diagram, I/O-bound vs. CPU-bound and which model fits each, `threading.active_count()`/`current_thread()`), 17.2 (three ways to create a thread — `target=`, subclassing, `ThreadPoolExecutor`; `.start()`'s once-only `RuntimeError`; `.join()`'s ordering guarantee demonstrated with and without it; `.name`/`.ident`/`.is_alive()`/`active_count()`/`enumerate()`; `.getName()`/`.setName()` flagged deprecated; `.isAlive()` flagged **removed** in Python 3.9), 17.3 (daemon threads — non-daemonic by default, `.daemon` must be set before `.start()`, legacy `.setDaemon()`/`.isDaemon()`, and a real subprocess-timed demo proving a daemon thread doesn't block process exit while a non-daemon one does), 17.4 (`multiprocessing.Process` mirroring `Thread`'s API, the `__main__`-guard requirement, a shared-memory-vs-separate-memory demo contrasting a thread and a process modifying the same global, IPC via `multiprocessing.Queue`), 17.5 (the GIL, tied back to 1.1.6 — timed proof that threads give no speedup for CPU-bound work, that processes do, and that threads DO speed up I/O-bound work), 17.6 (`asyncio` — coroutines, `await`, the event loop, `asyncio.gather()` proven concurrent by timing, the forgotten-`await` gotcha), 17.7 (a threading-vs-multiprocessing-vs-asyncio comparison table, a decision-tree diagram, and a demo mixing `asyncio` with `ProcessPoolExecutor`), 17.9 (race conditions made reliably visible via a manufactured read-sleep-write window, the `threading.Lock`/`with lock:` fix, and a one-liner table for `RLock`/`Semaphore`/`Event`) — all filled |
# | 18. Database Connectivity | `[DONE]` | 18.1 (why database connectivity beyond a plain file — concurrent access, complex queries, transactions, PEP 249's DB-API standardizing every driver's shape, `sqlite3` as the stdlib DB-API reference), 18.2 (`Connection` vs. `Cursor`, several independent cursors sharing one connection), 18.3 (`.execute()`/`.executemany()`, `.fetchone()`/`.fetchmany()`/`.fetchall()` compared, a cursor as its own lazy iterator, `.description` for column metadata), 18.4 (an f-string-built SQL injection demonstrated for real, then fixed with a `?` parameterized query), 18.5 (`.commit()`/`.rollback()`, a `try`/`except` rollback-on-failure demo, and the gotcha that `with conn:` only wraps commit/rollback — it does *not* close the connection, unlike `with open(...)`), 18.6 (a SQLite/PostgreSQL/MySQL driver comparison table, illustrative `psycopg2` reference syntax, and `sqlite3.apilevel`/`.paramstyle`/`.threadsafety` as real proof of DB-API compliance), 18.7 (ORM concepts — mapping tables to classes and rows to instances — a SQLAlchemy/Django-ORM/Peewee comparison table, and a verified-but-illustrative SQLAlchemy code cell contrasted directly with 18.1's raw `sqlite3` version of the same task) — all filled |
# | 19. Memory Management | `[DONE]` | 19.1 (object lifetime, a variable as a name bound to an object rather than a box, aliasing demonstrated via `is`/`id()`), 19.2 (reference counting, `sys.getrefcount()` and the +1 it always shows for its own temporary argument reference, deterministic `__del__` timing), 19.3 (a genuine reference cycle demonstrated with `gc.disable()`/`gc.collect()` — proving refcounting alone can't free a cycle, and that the cyclic collector can), 19.4 (`del` removes a name, not necessarily the object — demonstrated with two aliases — plus the common mistake of relying on `__del__` for deterministic cleanup instead of `with`, 16.6), 19.5 (the small-integer cache (-5 to 256) and string interning, `is` vs. `==` once a value falls outside the cache, `sys.intern()`), 19.6 (renumbered from the former 19.7 — `sys.getsizeof()` and `tracemalloc` for real memory inspection; the former 19.6 "Copying: Shallow versus Deep" was dropped as a duplicate of 5.1.2, which already covers `copy()`/`x[:]`/`copy.deepcopy()`), 19.9 (weak references via `weakref.ref()` — a reference that doesn't keep an object alive) — all filled |
# | 20. Data Validation, Parsing and Type Enforcement with Pydantic | `[DONE]` | 20.1 (why validation/parsing matter — a type-hint-not-enforced-at-runtime demo, then the manual-`isinstance`-checks boilerplate it motivates replacing), 20.2 (what Pydantic is — a `dataclass`-vs-`BaseModel` side-by-side showing the exact enforcement difference, `ValidationError` as a `ValueError` subclass), 20.3 (`BaseModel` basics — construction-as-validation, type coercion, `.model_dump()`/`.model_dump_json()`), 20.4 (`Field()` constraints, `Optional` fields, `default_factory` avoiding the mutable-default gotcha, recursively-validated nested models with exact nested-path error locations, `@field_validator` for custom/transforming logic), 20.5 (`.model_validate()`/`.model_validate_json()` for parsing external data, `model_config = {"frozen": True}` for immutable models), 20.6 (Pydantic in API development — a from-scratch request-validation-and-422-response demo reproducing what FastAPI does automatically, illustrative FastAPI wiring), 20.7 (Pydantic for LLM output enforcement — `.model_json_schema()` generating a schema to hand an LLM, parsing a stand-in LLM reply with `.model_validate_json()` including a constraint-violation failure case, illustrative OpenAI structured-output wiring) — all filled; a new chapter, not from the original skeleton |

# %% [markdown]
# ### 23.3 Cross-Reference Index
#
# Pointers for concepts that are discussed in one chapter but looked for in another.
#
# | Concept | Documented in | Also relevant to |
# |---|---|---|
# | Dynamic typing | 1.1.2 | — |
# | Everything is an object | 1.1.3 | 6.8 (functional programming builds on this) |
# | Interpreted / bytecode / PVM | 1.1.4 | — |
# | Platform independence, portability | 1.1.5 | 16.4 (portable path-building with `os.path.join()`/`pathlib`) |
# | Extensible vs embedded | 1.1.5 | — |
# | Interpreter performance | 1.1.6 | 17.5 (the GIL, timed proof of its CPU-bound-vs-I/O-bound effect) |
# | Identifiers and keywords | 1.2 | — |
# | `del` statement (names, list items/slices, dict keys, reference counting) | 2.5 | 5.1.2 (`pop()` contrast), 5.4.2 (dict key deletion); 10.2 (removing an instance attribute), 10.6 (`@property` deleters); 13.4 (`__delattr__`) |
# | Truthy/falsy values | 4.1 | 2.2.3 (`bool`) |
# | Mutating a list while iterating | 4.2.1 | 2.3.1 (`list` mutability) |
# | `range()` | 2.1 | 4.2.1 (`for` loops) |
# | `else` on `for`/`while` (loop-else) | 4.4 | — |
# | `try`/`except`/`else`/`finally` (`else`/`finally` angle on loops) | 4.4 | 7.2 (full syntax, multiple/tuple `except`, structural rules, nesting) |
# | Indexing and slicing (all sequences) | 5.1.1 | reused verbatim by `str` (5.2) and `tuple` (5.5) |
# | Slicing direction (position mapping, negative-index magnitude, forward/backward defaults) | 5.1.1 | — |
# | `list` internals (dynamic array of references) and indexing/slicing time complexity | 5.1.1 | 1.1.3 (everything is an object) |
# | List methods and built-in functions, with time complexity | 5.1.2 | 2.3.1 (`list` definition/mutability) |
# | Shallow vs. deep copy (`copy()`, `x[:]`, `copy.deepcopy()`) | 5.1.2 | 2.4 (object reuse/assignment) |
# | List comprehension | 5.1.3 | 14.5 (generator expressions, the lazy `()` counterpart) |
# | Stack/queue via `list` (`append`/`pop`/`pop(0)`) | 5.1.4 | 17 (`collections.deque` for an O(1)-both-ends queue, not yet covered); 11.4 (`Stack` built on `list` via delegation) |
# | String literal forms (quotes, raw, f-string) | 5.2.1 | 2.2.4 (`str` definition); 15.2 (raw strings for regex patterns) |
# | String searching (`find`/`index`/`rfind`/`rindex`/`count`) | 5.2.2 | 15 (regular expressions, for pattern-based searching) |
# | String replace/split/rsplit/join | 5.2.3 | — |
# | String case conversion | 5.2.4 | — |
# | String prefix/suffix/character-class checks | 5.2.5 | — |
# | String trimming and padding | 5.2.6 | — |
# | Set/frozenset internals (hash table) and membership time complexity | 5.3 | 5.1.1 (`list`'s O(n) scan, contrasted); 5.4 (`dict` shares the same hash table) |
# | Hashability requirement for set elements | 5.3.1 | 5.4.6, 5.5.4 (same rule for `dict` keys and tuple contents); 13.1 (`__hash__`) |
# | Mathematical set operations (union/intersection/difference/symmetric difference·XOR) | 5.3.3 | — |
# | `frozenset` and why it's hashable | 5.3.4 | 5.4.6, 5.5.4 (hashability, dict keys, tuple-as-key) |
# | Dictionary creation, access, methods, comprehension | 5.4.1–5.4.5 | 2.1 (`dict` definition) |
# | Hashing and dictionary keys (`hash()`, key requirements, equal-hash collisions) | 5.4.6 | 5.3.1, 5.5.4 (same hashability rule for set elements and tuples); 7.5 (`KeyError` on a missing dict key); 13.1 (`__hash__`) |
# | `tuple` internals (fixed-size array, vs. `list`'s over-allocation) | 5.5 | 5.1.1 |
# | Tuple creation, single-element comma gotcha | 5.5.1 | — |
# | Tuple methods (`count`, `index`) | 5.5.2 | — |
# | Tuple unpacking (extended `*`, nested, multiple return values) | 5.5.3 | 3.1.6 (basic unpacking); 6 (function return values) |
# | Why `tuple`: hashability and fixed-size "record" use | 5.5.4 | 5.4.6 (tuple as dict key) |
# | Grouping multiple exception types in one `except` | 5.5 (`tuple`) | 7.2 (`except (ValueError, ZeroDivisionError)`) |
# | Function basics (`def`, parameters vs. arguments, implicit `None` return) | 6.1 | — |
# | Positional vs. keyword arguments, the "keyword-then-positional" `SyntaxError`, multiple-values `TypeError` | 6.2.1 | — |
# | `*args` (variable positional args, keyword-only params after it) | 6.2.2 | 5.5 (`tuple`, what `args` actually is); 6.8.1 (lambda parameter forms) |
# | `**kwargs` (variable keyword args) | 6.2.3 | 5.4 (`dict`, what `kwargs` actually is); 6.8.1 (lambda parameter forms) |
# | Default argument values | 6.2 | 10.4 (default `__init__` arguments); 13.3 (as the alternative to unsupported overloading); 20.4 (`Field(default_factory=...)`, Pydantic's version of the same mutable-default fix) |
# | Recursion (base/recursive case, `RecursionError`) | 6.5 | 7.4 (`RecursionError`'s place in the exception hierarchy); 13.4 (the `__setattr__`/`__getattribute__` infinite-recursion trap); 14.4 (the iterative Fibonacci generator, contrasted with a recursive one) |
# | Type hinting (parameter/return annotations, `__annotations__`, container/`Optional` hints) | 6.6.1 | 10.9 (`dataclasses` field type annotations); 20.1 (the gotcha that hints are never enforced at runtime, and Pydantic's fix for that) |
# | `lambda` (anonymous functions): syntax, equivalence to `def`, single-expression restriction, late-binding closure gotcha | 6.8.1 | 6.2 (parameter forms), 3.1.7 (ternary as the lambda's branching tool), 6.8.3 (why the loop gotcha happens) |
# | `map()`, `filter()`, `reduce()`, `operator` module, custom higher-order functions | 6.8.2 | 5.1.2 (`sorted`/`reversed`, the same lazy-iterator idea), 5.1.3 (list comprehension as an alternative); 14.1 (`map`/`filter` are themselves lazy iterators, same protocol) |
# | Scope basics (local scope, enclosing scope), nested functions, closures, function factories, `nonlocal`, `__closure__` | 6.8.3 | 2.4 (rebinding vs. mutation), 10.2 (the same local-scope rule applied inside a method) |
# | Decorators — motivation (avoiding duplicated before/after logic), `@` syntax, `functools.wraps`, parameterized decorators, stacking order, decorator state via `nonlocal`, `functools.lru_cache` | 6.8.4 | 6.8.3 (closures, what a decorator is built from), 6.2.2/6.2.3 (`*args`/`**kwargs` in `wrapper`), 6.5 (`fibonacci()`, sped up by `lru_cache`); 10.3 (`@classmethod`/`@staticmethod`, 10.6 `@property` — the same decorator mechanism applied to methods) |
# | Errors vs. logical errors vs. exceptions (syntax error at parse time, logical error with no exception raised, runtime exception) | 7.1 | 7.2 (what `try`/`except` can actually act on) |
# | `try`/`except`/`else`/`finally` syntax, multiple/tuple `except` blocks, `except` order (subclass matching), the six structural validity rules, nesting | 7.2 | 4.4 (loop-else/try-else preview); 5.5 (tuple grouping); 6.1 (`return` inside `try`, `finally` still runs); 18.5 (rolling back a database transaction on failure) |
# | `raise`, bare-`raise` re-raising, exception chaining (implicit `__context__`, explicit `raise ... from ...` / `__cause__`, suppression via `raise ... from None`) | 7.3 | 7.5 (wrapping a low-level exception in a custom one, the main use of `raise ... from`) |
# | Exception hierarchy (`BaseException` vs `Exception`, `ArithmeticError`/`LookupError`/etc., `issubclass`, common built-ins, bare `except:` gotcha) | 7.4 | 6.5 (`RecursionError`); 5.1.1/5.4 (`IndexError`/`KeyError` sources); 14.2 (`StopIteration`, the exception that drives the whole iterator protocol); 20.2 (Pydantic's `ValidationError`, a plain `ValueError` subclass) |
# | Custom/user-defined exceptions (plain subclass, custom `__init__` with extra attributes, custom exception hierarchies) | 7.5 | 7.4 (mirrors the built-in hierarchy pattern); 7.3 (`raise ... from` for wrapping); 10.4 (`__init__` mechanics reused here) |
# | Exception handling practices (specific catches over bare `except:`, no silent swallowing, minimal `try` scope, EAFP vs. LBYL, cleanup via `finally`) | 7.6 | 7.2 (`finally`), 7.4 (bare `except:` gotcha), 5.4 (`in` check vs. `KeyError` — the LBYL/EAFP example) |
# | `assert` statement and `AssertionError`; exception object internals (`.args`, `str()` vs. `repr()`) | 7.9 | 7.2 (`try`/`except` mechanics), 7.5 (custom exception messages); 8.6 (`assert` used as a debugging technique) |
# | `print()` vs. `logging` (why not just print) | 8.1 | — |
# | Logger/Handler/Formatter roles, the 5 log levels, default level `WARNING` | 8.2 | — |
# | Module-level logger (`getLogger(__name__)`), `basicConfig`, once-per-process behavior/`force=True`, file logging (`filename`/`filemode` `"a"` vs `"w"`) | 8.3 | 16.2 (the same `"a"` vs. `"w"` mode distinction, for files in general) |
# | Debugging approaches overview (print vs. logging vs. assertions vs. interactive debugger) | 8.4 | 8.1–8.3, 8.5, 8.6 (each approach's own deep dive) |
# | `pdb`, `breakpoint()`, interactive debugger commands (`l`/`p`/`n`/`s`/`c`/`w`/`q`) | 8.5 | 8.6 (pairing an assertion with a breakpoint) |
# | `assert` as a fail-fast debugging technique | 8.6 | 7.9 (the statement's syntax/mechanics); 8.5 (`pdb`, for when the message alone isn't enough) |
# | What a module is, import forms (`import`/`as`/`from ... import`/`*`), special module members (`__name__`, `__doc__`, `__file__`, `__package__`, `__dict__`), `dir()` | 9.1 | 9.4 (`__name__` becoming `"__main__"`); 10.1 (class `__doc__`); 10.2 (an object's own `__dict__`, the same idea at instance level) |
# | `sys.path` search order, `sys.modules` caching (one execution per process), `.pyc`/`__pycache__` bytecode cache, `importlib.reload()` and its stale-instance caveat | 9.2 | 9.7 (site-packages as a `sys.path` entry) |
# | Packages, `__init__.py`, sub-packages, relative imports (`.`/`..`), `__all__` and `from package import *`, namespace packages (no `__init__.py`) | 9.3 | 9.9 (circular imports; `python -m` and relative-import package context) |
# | Scripts vs. modules, the `if __name__ == "__main__":` guard | 9.4 | 9.1 (`__name__`); 9.5 (`sys.argv` inside a guarded script); 17.4 (why `multiprocessing` needs this guard too) |
# | `sys.argv`, `argparse` (positional/optional args, `--help`, type conversion) | 9.5 | 9.4 (typically used inside the `__main__` guard) |
# | Standard library catalog (`os`, `sys`, `math`, `datetime`, `json`, `collections`, `itertools`, `re`, `pathlib`, `random`, `subprocess`, `functools`, `argparse`, `logging`) | 9.6 | 6.8.2/6.8.4 (`functools`); 8.1–8.3 (`logging`); 9.5 (`argparse`); 10.9 (`dataclasses`); 15 (`re`); 14.4 (`itertools.islice`, consuming an infinite generator); 16.4 (`pathlib`, building a portable path); 16.7 (`json`, structured-format summary) |
# | PyPI, `pip`, virtual environments (`venv`, `requirements.txt`), `sys.prefix` vs. `sys.base_prefix` | 9.7 | 9.2 (site-packages in the search path); 16.7 (`openpyxl`/`pypdf`, third-party packages installed this way); 20.2 (`pydantic`, another `pip install`-only package) |
# | Circular imports (name-level vs. module-level import, the fix) and `python -m` (relative-import package context) | 9.9 | 9.3 (relative imports, `__init__.py`/package context) |
# | Classes vs. objects/instances, identity of separate instances, class docstrings (`__doc__`/`help()`), what `self` is (`id(obj) == id(self)`) | 10.1 | 2.4 (`is`/identity, `id()`); 9.1 (`__doc__` at module level) |
# | Local vs. instance vs. class variables (overview), local variables inside a method/constructor and why they vanish, instance vs. class attributes, attribute lookup order, the mutable-class-attribute gotcha, dynamic attributes (`vars()`/`__dict__`), instance attributes created outside `__init__`, removing an instance attribute with `del` (from inside via `self`, from outside via a reference), declaring/reading/modifying a class attribute from every context (`__init__`, instance/class/static methods, outside the class), safely reading a class attribute via an instance with no shadow | 10.2 | 6.8.3 (local-scope rules, the same idea applied inside a method); 9.1 (module-level `__dict__`, one level up); 2.5 (`del`); 10.3 (`cls` inside a classmethod) |
# | Instance/class/static methods, bound methods vs. plain functions (`obj.method` vs. `Class.method(obj)`) | 10.3 | 6.8.4 (decorator mechanics, applied here to `@classmethod`/`@staticmethod`); 10.2 (`cls`/class-name access to class attributes) |
# | `__new__` vs. `__init__`, default constructor arguments, no constructor overloading (redefining `__init__` replaces it, doesn't overload it) | 10.4 | 6.2 (default argument values); 7.5 (custom exception `__init__`); 10.3 (`@classmethod` factories as the idiomatic alternative); 13.3 (the same overloading gotcha, revisited in depth) |
# | Access control conventions (`name`/`_name`/`__name`), name mangling | 10.5 | — |
# | `@property` (getter/setter/deleter), why a plain attribute can't add validation later | 10.6 | 2.5 (`del`, triggering a deleter); 6.8.4 (decorator mechanics); 12.6 (abstract properties combine the two); 13.4 (the idiomatic alternative to `get_x()`/`set_x()` methods, contrasted with the attribute-access dunders) |
# | Class design basics — cohesion, single responsibility, class vs. plain data structure | 10.7 | 11, 12 (how classes relate to and build on each other) |
# | `dataclasses` (auto-generated `__init__`/`__repr__`/`__eq__`), `object` as the universal base class | 10.9 | 6.6.1 (type annotations); 12 (inheritance, the class tree `object` sits at the root of); 20.2 (`BaseModel`, a `dataclass` look-alike that actually enforces its type hints) |
# | Association — the general "uses-a" relationship, one-directional/bidirectional, no ownership | 11.1 | 12 (contrasted with inheritance's "is-a") |
# | Aggregation — weak "has-a," part created outside and passed in, independent lifecycle, shareable across wholes | 11.2 | 11.3 (the stronger alternative, contrasted directly); 10.4 (constructor patterns) |
# | Composition — strong "owns-a," part built and owned internally, lifecycle tied to the whole, not shareable; aggregation-vs-composition comparison table; UML diamond notation | 11.3 | 11.2 (the weaker alternative); 10.4 (`__init__` building its own part) |
# | Delegation — reuse via "has-a" instead of "is-a," forwarding calls to a held object; `Stack` built on `list` vs. subclassing `list` directly | 11.4 | 5.1 (`list` methods being reused/hidden); 12 (contrasted with inheritance-based reuse) |
# | Choosing between association/aggregation/composition/delegation — decision-path diagram, summary table, a capstone example combining all four | 11.5 | 11.1–11.4 (each relationship's own deep dive) |
# | Base/derived classes, "is-a" (contrasted with 11's "has-a"/"uses-a"), `isinstance`/`issubclass` across an inheritance chain | 12.1 | 11 (relationships without inheritance, for contrast) |
# | Single/multiple/multilevel/hierarchical/hybrid inheritance, the diamond shape | 12.2 | 12.5 (why the diamond makes lookup order ambiguous, and how it's resolved) |
# | Method overriding — same-name redefinition replaces the parent's version | 12.3 | 12.4 (`super()`, for reaching the replaced version deliberately); 13.3 (overriding contrasted directly with unsupported overloading) |
# | `super()` — reusing a parent `__init__`, extending an overridden method, cooperative multiple inheritance (follows the MRO, not "the direct parent"), the explicit `super(Class, self)` form | 12.4 | 12.5 (the MRO `super()` actually walks); 10.4 (`__init__` patterns); 12.3 (method overriding); 13.4 (`super().__setattr__()`/`super().__getattribute__()` delegation, the same mechanism applied to attribute-access dunders) |
# | Method Resolution Order (MRO), `__mro__`/`mro()`, C3 linearization formula, the merge operation's four rules, a simple-diamond trace, the classic `K1`/`K2`/`K3`/`Z` example (drawn as a shared-leaves tree) traced via a from-scratch `merge()`/`linearize()` implementation, inconsistent-hierarchy `TypeError` | 12.5 | 12.2 (the diamond shape that motivates it); 12.4 (`super()`'s actual lookup order) |
# | Abstract classes/interfaces — `NotImplementedError`-by-convention vs. `abc.ABC`/`@abstractmethod` enforcement, instantiation blocked until every abstract method is implemented, abstract properties | 12.6 | 10.6 (`@property`, combined with `@abstractmethod`); 12.1 (a class meant only to be subclassed, never instantiated) |
# | Dunder/magic methods — the `a + b` → `type(a).__add__(a, b)` mechanism, a full catalog by category (construction, representation, arithmetic normal/reflected/in-place, comparison, hashing, container, iteration, callable, context manager, attribute access, truthiness), a `__eq__`/`__lt__` comparison demo (identity vs. value equality, the `</>`/`==`/`!=` reflected-pairing rules, `__ne__` auto-inverting `__eq__`), which dunders are Python-3-only vs. renamed from Python 2 (`__matmul__` family added in 3.5/PEP 465; `__div__`/`__idiv__` → `__truediv__`/`__itruediv__`, `next()` → `__next__()`, `__nonzero__` → `__bool__`), and a closing "what's allowed" overloading-vs-overriding summary table | 13.1 | 10.4 (`__init__`/`__new__`); 13.2 (arithmetic dunders in depth); 2.4 (identity vs. `__eq__`); 13.4 (attribute-access dunders, the same mechanism applied to `obj.attr`); 14.1/14.2 (`__iter__`/`__next__`, the same dunder mechanism applied to iteration); 16.6 (`__enter__`/`__exit__`, the same mechanism applied to `with`) |
# | Operator overloading — `__add__`, reflected methods (`__radd__`) and why `int + CustomClass` fails without one, the `sum()`-needs-`__radd__` gotcha and its fix, `__iadd__` vs. falling back to `__add__` (mutation vs. a new object), the full normal/reflected/in-place table for every arithmetic operator (`@`/matrix-mult flagged as Python 3.5+) | 13.2 | 5.1.2 (`list` methods, contrasted with operator-based reuse); 13.1 (the general dunder mechanism, version notes, and "what's allowed" summary) |
# | Method/constructor overloading is not supported (redefinition replaces, doesn't overload) vs. overriding (fully supported) — contrasted directly, plus the idiomatic default-argument alternative | 13.3 | 10.4 (`__init__` no-overloading gotcha, first shown); 12.3 (method overriding); 6.2 (default argument values); 13.1 ("what's allowed" summary table) |
# | Getter/setter methods (`get_x()`/`set_x()`) and the four attribute-access dunders — `__getattr__` (lookup-failure fallback), `__setattr__` (runs on every assignment, its infinite-recursion trap and `super()` fix), `__delattr__`, `__getattribute__` (runs on every read, the most powerful/dangerous of the four) | 13.4 | 10.6 (`@property`, the idiomatic alternative to plain getter/setter methods); 2.5 (`del obj.attr`, what `__delattr__` intercepts); 12.4 (`super()` delegation, the same mechanism used here) |
# | Iterable vs. iterator — the `__iter__`/`__next__` requirement split, `iter()`/`next()` manual demo, why a list is reusable but a specific iterator, once exhausted, stays exhausted | 14.1 | 13.1 (the dunder mechanism generally); 5.1.3 (list comprehension, contrasted with 14.5's lazy generator expression); 16.5 (a file object as an iterator, the idiomatic line-by-line pattern) |
# | The iterator protocol — a `for` loop desugared into its literal `iter()`/`next()`/`StopIteration` form | 14.2 | 7.4 (`StopIteration`'s place in the exception hierarchy); 13.1 (dunder-call mechanism) |
# | Custom iterator classes — `__iter__` returning `self`, `__next__` raising `StopIteration`, and the resulting single-use-only gotcha | 14.3 | 14.1 (the same reusable-vs-exhausted distinction, here caused by design rather than by consuming an iterator directly) |
# | Generator functions — `yield`'s pause/resume mechanism, local state preserved between calls, automatic `StopIteration` on return, the list-vs-generator memory trade-off (`sys.getsizeof`), a bounded and an infinite Fibonacci generator consumed via `itertools.islice` | 14.4 | 14.3 (what a generator function saves you from writing by hand); 9.6 (`itertools.islice`); 6.5 (recursion as the other classic Fibonacci implementation, contrasted here with iteration); 19.6 (`sys.getsizeof()` used again, for memory inspection generally) |
# | Generator expressions — `()` vs. `[]`, lazy vs. eager, single-use exhaustion, the parens-optional `sum(... for ...)` idiom | 14.5 | 5.1.3 (list comprehension, the eager counterpart); 14.4 (generator functions, the non-expression form) |
# | Advanced generator behaviour — `send()` for two-way communication, `close()`, `yield from` delegation | 14.6 | 14.4 (the pause/resume mechanism `send()` builds on) |
# | Laziness/memory/performance summary (list vs. generator trade-off table), `len()`/indexing `TypeError`s on generators | 14.7 | 14.4 (the memory comparison this table summarizes); 5.1.1 (indexing/slicing, which generators cannot support) |
# | Regex fundamentals — what a regular expression is, general applications (validation/search/replace/split), a motivating plain-string-methods-vs-regex comparison | 15.1 | 5.2.2 (string searching methods, the non-pattern-based alternative) |
# | The `re` module — patterns as plain strings, the raw-string-vs-escape-sequence gotcha, `re.compile()` for a reusable `Pattern` object, `.finditer()` returning a lazy iterator of `Match` objects (`.group()`/`.start()`/`.end()`/`.span()`) | 15.2 | 5.2.1 (raw string literals); 14.1/14.2 (the iterator protocol `finditer()` returns); 14.5 (`findall()` vs. `finditer()`, the same eager-vs-lazy split as a list comprehension vs. a generator expression) |
# | Character classes — `[...]`, ranges (`a-z`, `0-9`), negation via a leading `^` | 15.3 | 15.4 (the predefined one-character shorthands for the most common classes) |
# | Predefined character classes — `\d`/`\D`/`\w`/`\W`/`\s`/`\S`/`.`, and the `\b` word-boundary gotcha (a zero-width assertion, not a character class) | 15.4 | 15.3 (the custom `[...]` classes these are shorthand for) |
# | Quantifiers — `*`/`+`/`?`/`{n}`/`{n,}`/`{n,m}`, and greedy vs. lazy matching (the `?` suffix) | 15.5 | 15.3, 15.4 (the classes/characters quantifiers attach to) |
# | Full `re` function catalog — `match`/`fullmatch`/`search`/`findall`/`finditer`/`sub`/`subn`/`split`/`compile`/`escape`, each with a short example | 15.6 | 15.2 (`compile()`/`finditer()`, covered in depth there) |
# | Why file handling exists — persisting data beyond a process's lifetime, in-memory vs. temporary vs. permanent storage, text vs. binary files, an `.encode()` demo showing the text/bytes boundary | 16.1 | 5.2.1 (`str`, what gets encoded); 16.2 (text open modes, the next step) |
# | Text file open modes — `r`/`w`/`a`/`x`/`r+`/`w+`/`a+`, the implicit `"t"` suffix, `x`'s `FileExistsError`, `r+`'s no-truncation overwrite | 16.2 | 16.3 (the binary counterpart of every mode here); 8.3 (`logging`'s own `"a"` vs. `"w"` `filemode`) |
# | Binary file open modes — `rb`/`wb`/`ab`/`xb`/`rb+`/`wb+`/`ab+`, one-liner per mode | 16.3 | 16.2 (the text mode each one mirrors); 16.1 (text vs. binary, the distinction these modes express) |
# | The file object's properties (`.name`/`.mode`/`.encoding`/`.closed`/`.writable()`/`.readable()`), `.write()`'s return value, resolving a path in `open()` (relative-to-cwd vs. absolute), building a portable path with `os.path.join()`/`pathlib` | 16.4 | 1.1.5 (platform independence, applied to path separators); 9.6 (`pathlib`); 9.1 (`__name__`/`__file__`, other "name" attributes on other kinds of objects) |
# | Reading character data — `.read(n)`/`.read()`/`.readline()`/`.readlines()` compared, then iterating the file object directly as the idiomatic lazy line-by-line approach | 16.5 | 14.1, 14.2 (the iterator protocol a file object itself implements) |
# | The `with` statement for files — why a bare `.close()` can be skipped by an exception, `__enter__`/`__exit__` guaranteeing it runs regardless | 16.6 | 13.1 (the `__enter__`/`__exit__` context-manager dunders, in the general catalog); 17.9 (`with lock:`, the same context-manager pattern applied to a `threading.Lock`); 18.5 (`with conn:`, whose context manager notably does NOT close the connection, unlike this one); 19.4 (the reliable alternative to relying on `__del__` for deterministic cleanup) |
# | Other structured file formats — CSV/JSON/Excel/PDF summarized in one table, a full `csv.writer`/`csv.reader`/`csv.DictReader` demo, and reference syntax for `openpyxl`/`pypdf` | 16.7 | 9.6 (`json`, already covered there); 9.7 (`pip install`, for the non-stdlib packages); 16.5 (plain `.read()`/`.write()`, contrasted with format-aware parsing) |
# | Thread vs. process, concurrency vs. parallelism (a static ASCII diagram), I/O-bound vs. CPU-bound and which concurrency tool fits each, `threading.active_count()`/`current_thread()` | 17.1 | 1.1.6 (the interpreter-performance limitation this chapter explains); 17.4 (the process side of the thread/process table) |
# | Creating a thread three ways (`target=`, subclassing, `ThreadPoolExecutor`), `.start()`'s once-only `RuntimeError`, `.join()`'s ordering guarantee, `.name`/`.ident`/`.is_alive()`/`active_count()`/`enumerate()`, `.getName()`/`.setName()` deprecated, `.isAlive()` removed in Python 3.9 | 17.2 | 13.1 (dunder mechanism generally); 6.8.4 (decorator-like wrapping, contrasted with subclassing `Thread`) |
# | Daemon threads — non-daemonic by default, `.daemon` must be set before `.start()`, legacy `.setDaemon()`/`.isDaemon()`, a subprocess-timed proof of the exit-behaviour difference | 17.3 | 17.2 (`.daemon`'s `RuntimeError` mirrors `.start()`'s once-only rule) |
# | `multiprocessing.Process` (mirrors `Thread`'s API), the `__main__`-guard requirement, shared memory (threads) vs. separate memory (processes) made concrete, IPC via `multiprocessing.Queue` | 17.4 | 9.4 (the `__main__` guard); 17.1 (thread-vs-process table); 17.5 (why processes bypass the GIL) |
# | The GIL — one lock, one thread executing Python bytecode at a time; timed proof threads don't speed up CPU-bound work but processes do, and that threads DO speed up I/O-bound work | 17.5 | 1.1.6 (the limitation this section explains in full); 17.2, 17.4 (the threads/processes being timed) |
# | `asyncio` — coroutine functions, `await` as a cooperative handoff point, the event loop, `asyncio.gather()` proven concurrent by timing, the forgotten-`await` gotcha | 17.6 | 14.4 (`yield`'s pause/resume mechanism — the same underlying idea, applied to concurrency instead of iteration) |
# | Choosing between threading/multiprocessing/`asyncio` — a comparison table, a decision-tree diagram, and a demo mixing `asyncio` with `ProcessPoolExecutor` | 17.7 | 17.2, 17.4, 17.6 (each model's own deep dive) |
# | Race conditions made reliably visible via a manufactured read-sleep-write window, the `threading.Lock`/`with lock:` fix, and `RLock`/`Semaphore`/`Event` one-liners | 17.9 | 16.6 (`with`, the same context-manager mechanism); 17.2 (the shared-memory property of threads that makes races possible in the first place) |
# | Why database connectivity beyond a plain file, PEP 249's DB-API standardizing every driver's shape, `sqlite3` as the stdlib DB-API reference | 18.1 | 16 (plain files, the alternative this chapter improves on); 9.6 (`sqlite3` in the stdlib catalog) |
# | `Connection` vs. `Cursor`, several independent cursors sharing one connection | 18.2 | 18.1 (`sqlite3.connect()` returning the `Connection`) |
# | `.execute()`/`.executemany()`, `.fetchone()`/`.fetchmany()`/`.fetchall()` compared, a cursor as its own lazy iterator, `.description` for column metadata | 18.3 | 14.1, 14.2 (the iterator protocol a `Cursor` implements); 16.5 (iterating a file object, the same idea) |
# | An f-string-built SQL injection demonstrated for real, then fixed with a `?` parameterized query | 18.4 | 18.6 (the `%s` placeholder style other drivers use instead of `?`) |
# | `.commit()`/`.rollback()`, rollback-on-failure via `try`/`except`, and the gotcha that `with conn:` only wraps commit/rollback — it does *not* close the connection | 18.5 | 7.2 (`try`/`except`, reused here for transaction safety); 16.6 (`with open(...)`, contrasted directly with `with conn:`'s narrower behaviour) |
# | SQLite/PostgreSQL/MySQL driver comparison, `sqlite3.apilevel`/`.paramstyle`/`.threadsafety` as real proof of DB-API compliance | 18.6 | 9.7 (`pip install`, for the non-stdlib drivers); 18.4 (the placeholder-style difference between drivers) |
# | ORM concepts — mapping tables to classes and rows to instances — a SQLAlchemy/Django-ORM/Peewee comparison table, and an illustrative SQLAlchemy example | 18.7 | 18.1 (the raw `sqlite3` version of the same task, contrasted directly); 9.7 (`pip install`, for adding an ORM) |
# | Object lifetime — a variable as a name bound to an object rather than a box, aliasing demonstrated via `is`/`id()` | 19.1 | 1.1.3 (everything is an object); 2.4 (assignment as name-binding, not copying) |
# | Reference counting — `sys.getrefcount()` (and the +1 it always shows for its own temporary argument reference), deterministic `__del__` timing the instant a count hits zero | 19.2 | 13.1 (`__del__` in the construction/destruction dunder row); 19.4 (`del`, one way a count goes down) |
# | Garbage collection — a genuine reference cycle demonstrated with `gc.disable()`/`gc.collect()`, proving refcounting alone can't free a cycle but the cyclic collector can | 19.3 | 19.2 (the refcounting mechanism this backstops); 19.4 (the `__del__`-timing gotcha a cycle causes) |
# | `del` removes a name binding, not necessarily the object — demonstrated with two aliases — plus the common mistake of relying on `__del__` for deterministic cleanup instead of `with` | 19.4 | 2.5 (`del`'s syntax for names/list items/dict keys); 16.6 (`with`, the reliable alternative); 19.3 (the cycle that can delay `__del__`) |
# | Small-integer caching (-5 to 256) and string interning, `is` vs. `==` once a value falls outside the cache, `sys.intern()` | 19.5 | 2.4 (`is`/identity); 5.5.4 (hashability, a related "why immutable values behave specially" idea) |
# | `sys.getsizeof()` and `tracemalloc` for real memory inspection | 19.6 | 14.4 (`sys.getsizeof()`, first used to compare a list and a generator) |
# | Weak references via `weakref.ref()` — a reference that doesn't keep an object alive | 19.9 | 19.1, 19.2 (ordinary references, contrasted directly) |
# | Why data validation/parsing matter — a type-hint-not-enforced-at-runtime demo, and the manual `isinstance`-checks boilerplate it motivates replacing | 20.1 | 6.6.1 (type hints, and the gotcha that they're documentation only) |
# | What Pydantic is — a `dataclass`-vs-`BaseModel` side-by-side showing the exact enforcement difference, `ValidationError` as a `ValueError` subclass | 20.2 | 10.9 (`dataclasses`, the look-alike Pydantic models are compared against); 7.4 (`ValidationError`'s place in the exception hierarchy); 9.7 (`pip install pydantic`) |
# | `BaseModel` basics — construction-as-validation, type coercion, `.model_dump()`/`.model_dump_json()` | 20.3 | 20.2 (why this differs from a plain `dataclass`) |
# | `Field()` constraints, `Optional` fields, `default_factory`, recursively-validated nested models with exact nested-path error locations, `@field_validator` for custom/transforming logic | 20.4 | 6.2 (default argument values, and the mutable-default gotcha `default_factory` avoids) |
# | `.model_validate()`/`.model_validate_json()` for parsing external data, `model_config = {"frozen": True}` for immutable models | 20.5 | 20.3 (the coercion behaviour these build on) |
# | Pydantic in API development — a from-scratch request-validation-and-422-response demo reproducing what FastAPI does automatically | 20.6 | 20.5 (`.model_validate()`, the mechanism underneath) |
# | Pydantic for LLM output enforcement — `.model_json_schema()` generating a schema to hand an LLM, parsing a stand-in LLM reply with `.model_validate_json()` | 20.7 | 20.5 (`.model_validate_json()`, reused here); 20.1 (an LLM's raw reply as untrusted external input, the chapter's opening motivation) |
# |  |  |  |

# %% [markdown]
# ### 23.4 Environment Notes
#
# Python version, OS and any environment detail that affects the behaviour recorded in
# experiments.
#
# > _Content to be added from handwritten notes._

# %%
# --- Environment check ---
import sys, platform
print(sys.version)
print(platform.platform())
